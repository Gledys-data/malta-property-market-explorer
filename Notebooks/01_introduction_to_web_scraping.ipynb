# %% [markdown]
# # Malta Property Market Explorer
#
# ## Introduction
#
# This notebook marks the beginning of the **Malta Property Market Explorer** project.
#
# This project started as a way to improve my Python skills, but it also solves a real problem I have: finding the right house to buy in Malta.
#
# My goal is to learn and apply web scraping, data collection, data cleaning, and data analysis using real property listings from the Malta real estate market. As the project grows, I also plan to explore APIs and data visualization to build a complete data analysis workflow.
#
# By the end of this project, I hope to create a dataset that allows me to compare properties across different areas of Malta based on price, location, property type, and other important features. This project combines learning with a practical objective, making it both a valuable portfolio piece and a useful decision-making tool for my future home purchase.
#
#
# ## Week 1 | Day 1
#
# ### Objectives
#
# - Create project structure
# - Prepare GitHub repository
# - Install required libraries
# - Verify Python environment

# %%
import requests
import bs4
import pandas as pd
import matplotlib

print("Environment successfully configured!")
# Out:
# Environment successfully configured!

# %% [markdown]
# ## Day 1 Summary
#
# The project structure was created and the Python environment was tested.
#
# All required libraries were successfully imported:
#
# - requests
# - BeautifulSoup / bs4
# - pandas
# - matplotlib
#
# Next step: test access to a property website and inspect HTML content.
